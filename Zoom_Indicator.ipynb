# %%
import panel as pn
pn.extension(sizing_mode="stretch_width")
import geopandas as gpd
import pandas as pd
import folium as fm
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install geopandas
import geopandas as gpd
# Out:
# Requirement already satisfied: geopandas in c:\users\najmi.ariffin\anaconda3\lib\site-packages (0.6.1)
# Requirement already satisfied: fiona in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from geopandas) (1.8.4)
# Requirement already satisfied: pyproj in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\najmi.ariffin\appdata\roaming\python\python38\site-packages (from geopandas) (1.2.3)
# Requirement already satisfied: shapely in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from geopandas) (1.8.1.post1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (1.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->geopandas) (1.15.0)
# Requirement already satisfied: attrs>=17 in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from fiona->geopandas) (20.3.0)
# Requirement already satisfied: click<8,>=4.0 in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from fiona->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: certifi in c:\users\najmi.ariffin\anaconda3\lib\site-packages (from pyproj->geopandas) (2022.6.15)

# %%
import panel as pn
pn.extension(sizing_mode="stretch_width")

import json
import urllib.request
  
# Opening JSON file
#f = open('https://raw.githubusercontent.com/dosm-malaysia/data-open/main/datasets/geodata/electoral_1_dun.geojson')
url = 'https://raw.githubusercontent.com/dosm-malaysia/data-open/main/datasets/geodata/electoral_1_dun.geojson'

geo_json = json.load(urllib.request.urlopen(url))

# returns JSON object as a dictionary
#geo_json = json.load(f)

# %% [markdown]
# #READ DATAFRAME

# %%
# !pip install pandas_geojson -qq

# %%
from pandas_geojson import read_geojson, filter_geojson
filter = ['Pulau Pinang']
select = filter_geojson(geo_json=geo_json, filter_list=filter, property_key='state')

# %%
duns = gpd.read_file("https://raw.githubusercontent.com/dosm-malaysia/data-open/main/datasets/geodata/electoral_1_dun.geojson")

# %%
dunspp = duns[duns['state']== 'Pulau Pinang']

# %%
dunspp['dun']
# Out:
# 243                N.01 Penaga
# 244                N.02 Bertam
# 245        N.03 Pinang Tunggal
# 246    N.04 Permatang Berangan
# 247            N.05 Sungai Dua
# 248      N.06 Telok Ayer Tawar
# 249           N.07 Sungai Puyu
# 250          N.08 Bagan Jermal
# 251           N.09 Bagan Dalam
# 252         N.10 Seberang Jaya
# 253       N.11 Permatang Pasir
# 254               N.12 Penanti
# 255               N.13 Berapit
# 256         N.14 Machang Bubuk
# 257         N.15 Padang Lalang
# 258                 N.16 Perai
# 259          N.17 Bukit Tengah
# 260          N.18 Bukit Tambun
# 261                  N.19 Jawi
# 262          N.20 Sungai Bakap
# 263          N.21 Sungai Acheh
# 264         N.22 Tanjong Bunga
# 265             N.23 Air Putih
# 266           N.24 Kebun Bunga
# 267           N.25 Pulau Tikus
# 268           N.26 Padang Kota
# 269        N.27 Pengkalan Kota
# 270                N.28 Komtar
# 271         N.29 Datok Keramat
# 272         N.30 Sungai Pinang
# 273          N.31 Batu Lancang
# 274           N.32 Seri Delima
# 275              N.33 Air Itam
# 276         N.34 Paya Terubong
# 277             N.35 Batu Uban
# 278        N.36 Pantai Jerejak
# 279            N.37 Batu Maung
# 280           N.38 Bayan Lepas
# 281          N.39 Pulau Betong
# 282          N.40 Telok Bahang
# Name: dun, dtype: object

# %% [markdown]
# #READ GEOJSON

# %%
select = pn.widgets.Select(name='Select', options=["N.01 Penaga",
"N.02 Bertam",
"N.03 Pinang Tunggal",
"N.04 Permatang Berangan",
"N.05 Sungai Dua",
"N.06 Telok Ayer Tawar",
"N.07 Sungai Puyu",
"N.08 Bagan Jermal",
"N.09 Bagan Dalam",
"N.10 Seberang Jaya",
"N.11 Permatang Pasir",
"N.12 Penanti",
"N.13 Berapit",
"N.14 Machang Bubuk",
"N.15 Padang Lalang",
"N.16 Perai",
"N.17 Bukit Tengah",
"N.18 Bukit Tambun",
"N.19 Jawi",
"N.20 Sungai Bakap",
"N.21 Sungai Acheh",
"N.22 Tanjong Bunga",
"N.23 Air Putih",
"N.24 Kebun Bunga",
"N.25 Pulau Tikus",
"N.26 Padang Kota",
"N.27 Pengkalan Kota",
"N.28 Komtar",
"N.29 Datok Keramat",
"N.30 Sungai Pinang",
"N.31 Batu Lancang",
"N.32 Seri Delima",
"N.33 Air Itam",
"N.34 Paya Terubong",
"N.35 Batu Uban",
"N.36 Pantai Jerejak",
"N.37 Batu Maung",
"N.38 Bayan Lepas",
"N.39 Pulau Betong",
"N.40 Telok Bahang"])

select
# Out:
# Select(options=['N.01 Penaga', ...], sizing_mode='stretch_width', value='N.01 Penaga')

# %%
select_option = pn.Row(select.controls(jslink=True), select)

# %%
#select_option

# %%
selectv = select.value

# %%
selectv
# Out:
# 'N.01 Penaga'

# %%
from pandas_geojson import read_geojson, filter_geojson
filter = [selectv]
selectgeo = filter_geojson(geo_json=geo_json, filter_list=filter, property_key='dun')

# %%
import folium as fm
from folium import plugins

map = fm.Map(location = [5.016806622688496, 107.9456777002687], tiles='cartodbpositron', zoom_start = 6)

# Adds tool measure to the top right
#from folium.plugins import MeasureControl
#map.add_child(MeasureControl())

#map geojson
fm.GeoJson(selectgeo, name='DUN boundary',tooltip=fm.GeoJsonTooltip(fields=['dun', 'parlimen'])).add_to(map)
map.fit_bounds(map.get_bounds(), padding=(30, 30))
#map
folium_map = pn.panel(map, height=400)
folium_map
# Out:
# Folium(Map, height=400)

# %%
selectv
# Out:
# 'N.01 Penaga'

# %%
sociodemo = pd.read_csv('https://github.com/booluckgmie/podac/raw/main/sociodemo.csv')

# %%
select_sociodemo = sociodemo[sociodemo['dun']== selectv]

# %%
select_sociodemo
# Out:
#     area_type          dun  max_elevation  watercover         state  \
# 130       sla  N.01 Penaga           31.0    0.632583  Pulau Pinang
#
#                parlimen  population_total  sex_male  sex_female  \
# 130  P.041 Kepala Batas             28207     14243       13964
#
#      housing_total  household_total
# 130           7897             6976

# %%
select_sociodemo['watercover'] = np.round(select_sociodemo.watercover, decimals = 3)
# Out:
# <ipython-input-61-6223770fcf7b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   select_sociodemo['watercover'] = np.round(select_sociodemo.watercover, decimals = 3)

# %%
max_elev = select_sociodemo['max_elevation'].iloc[0]
water = select_sociodemo['watercover'].iloc[0]
pop = select_sociodemo['population_total'].iloc[0]

# %%
water
# Out:
# 0.633

# %%
#max_elev = pn.indicators.Number(name='Maximum Elevation', value=max_elev, format='{value}%', colors=[(33, 'green')])

# %%
#pn.indicators.Number(name='Maximum Elevation', value=value, format='{value}')

# %%
#pn.Row(max_elev.clone(value=value, format='{value}%', colors=[(3, 'green')]))

# %%
number = pn.indicators.Number(format='{value}'    
)

indicator = pn.Row(number.clone(name='Population', value=pop, colors=[(33, 'black')]), 
       number.clone(name='Maximum Elevation', value=max_elev, colors=[(66, 'blue')]), 
       number.clone(name='Surface covered in water', value=water, colors=[(100, 'red')]),sizing_mode='stretch_width')

# %%
#indicator

# %%
description = select_sociodemo['dun'].iloc[0]

#str_pane = pn.pane.Str(str(description), style={'font-size': '100pt'})
#str_pane

str_pane = pn.indicators.Number(name=str(description))

# %%
app2 = pn.Column(
    select,
    pn.Column(        
        str_pane,
        indicator,
        folium_map,
        sizing_mode='scale_both'
    ),
    sizing_mode='scale_both'
)
app2
# Out:
# Column(sizing_mode='scale_both')
#     [0] Select(options=['N.01 Penaga', ...], sizing_mode='stretch_width', value='N.01 Penaga')
#     [1] Column(sizing_mode='scale_both')
#         [0] Number(name='N.01 Penaga')
#         [1] Row(sizing_mode='stretch_width')
#             [0] Number(colors=[(33, 'black')], name='Population', value=28207)
#             [1] Number(colors=[(66, 'blue')], name='Maximum Elevation', value=31.0)
#             [2] Number(colors=[(100, 'red')], name='Surface covered i..., value=0.633)
#         [2] Folium(Map, height=400)

# %%
app2.save('indicator.html', resources=INLINE, embed=True)

#app.save('datatable.html')
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: HTML(id='2096', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: HTML(id='2097', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: HTML(id='2098', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: HTML(id='2094', ...)
